# %% [markdown]
# # trivial agent metrics

# %%
# %matplotlib notebook

# %%
from board import Board
from trivial_agent import TrivialAgent

# %%
angt.play_until_completion(debug=False)
# Out:
# 96

# %%
n = 1000 
scores = list() 

for i in range(n): 
    board = Board(vis=False, playmode=False)
    agent = TrivialAgent(board)
    
    scores.append(agent.play_until_completion())
    print(f"Iter {i} of {n} complete.")
# Out:
# Iter 0 of 1000 complete.
# Iter 1 of 1000 complete.
# Iter 2 of 1000 complete.
# Iter 3 of 1000 complete.
# Iter 4 of 1000 complete.
# Iter 5 of 1000 complete.
# Iter 6 of 1000 complete.
# Iter 7 of 1000 complete.
# Iter 8 of 1000 complete.
# Iter 9 of 1000 complete.
# Iter 10 of 1000 complete.
# Iter 11 of 1000 complete.
# Iter 12 of 1000 complete.
# Iter 13 of 1000 complete.
# Iter 14 of 1000 complete.
# Iter 15 of 1000 complete.
# Iter 16 of 1000 complete.
# Iter 17 of 1000 complete.
# Iter 18 of 1000 complete.
# Iter 19 of 1000 complete.
# Iter 20 of 1000 complete.
# Iter 21 of 1000 complete.
# Iter 22 of 1000 complete.
# Iter 23 of 1000 complete.
# Iter 24 of 1000 complete.
# Iter 25 of 1000 complete.
# Iter 26 of 1000 complete.
# Iter 27 of 1000 complete.
# Iter 28 of 1000 complete.
# Iter 29 of 1000 complete.
# Iter 30 of 1000 complete.
# Iter 31 of 1000 complete.
# Iter 32 of 1000 complete.
# Iter 33 of 1000 complete.
# Iter 34 of 1000 complete.
# Iter 35 of 1000 complete.
# Iter 36 of 1000 complete.
# Iter 37 of 1000 complete.
# Iter 38 of 1000 complete.
# Iter 39 of 1000 complete.
# Iter 40 of 1000 complete.
# Iter 41 of 1000 complete.
# Iter 42 of 1000 complete.
# Iter 43 of 1000 complete.
# Iter 44 of 1000 complete.
# Iter 45 of 1000 complete.
# Iter 46 of 1000 complete.
# Iter 47 of 1000 complete.
# Iter 48 of 1000 complete.
# Iter 49 of 1000 complete.
# Iter 50 of 1000 complete.
# Iter 51 of 1000 complete.
# Iter 52 of 1000 complete.
# Iter 53 of 1000 complete.
# Iter 54 of 1000 complete.
# Iter 55 of 1000 complete.
# Iter 56 of 1000 complete.
# Iter 57 of 1000 complete.
# Iter 58 of 1000 complete.
# Iter 59 of 1000 complete.
# Iter 60 of 1000 complete.
# Iter 61 of 1000 complete.
# Iter 62 of 1000 complete.
# Iter 63 of 1000 complete.
# Iter 64 of 1000 complete.
# Iter 65 of 1000 complete.
# Iter 66 of 1000 complete.
# Iter 67 of 1000 complete.
# Iter 68 of 1000 complete.
# Iter 69 of 1000 complete.
# Iter 70 of 1000 complete.
# Iter 71 of 1000 complete.
# Iter 72 of 1000 complete.
# Iter 73 of 1000 complete.
# Iter 74 of 1000 complete.
# Iter 75 of 1000 complete.
# Iter 76 of 1000 complete.
# Iter 77 of 1000 complete.
# Iter 78 of 1000 complete.
# Iter 79 of 1000 complete.
# Iter 80 of 1000 complete.
# Iter 81 of 1000 complete.
# Iter 82 of 1000 complete.
# Iter 83 of 1000 complete.
# Iter 84 of 1000 complete.
# Iter 85 of 1000 complete.
# Iter 86 of 1000 complete.
# Iter 87 of 1000 complete.
# Iter 88 of 1000 complete.
# Iter 89 of 1000 complete.
# Iter 90 of 1000 complete.
# Iter 91 of 1000 complete.
# Iter 92 of 1000 complete.
# Iter 93 of 1000 complete.
# Iter 94 of 1000 complete.
# Iter 95 of 1000 complete.
# Iter 96 of 1000 complete.
# Iter 97 of 1000 complete.
# Iter 98 of 1000 complete.
# Iter 99 of 1000 complete.
# Iter 100 of 1000 complete.
# Iter 101 of 1000 complete.
# Iter 102 of 1000 complete.
# Iter 103 of 1000 complete.
# Iter 104 of 1000 complete.
# Iter 105 of 1000 complete.
# Iter 106 of 1000 complete.
# Iter 107 of 1000 complete.
# Iter 108 of 1000 complete.
# Iter 109 of 1000 complete.
# Iter 110 of 1000 complete.
# Iter 111 of 1000 complete.
# Iter 112 of 1000 complete.
# Iter 113 of 1000 complete.
# Iter 114 of 1000 complete.
# Iter 115 of 1000 complete.
# Iter 116 of 1000 complete.
# Iter 117 of 1000 complete.
# Iter 118 of 1000 complete.
# Iter 119 of 1000 complete.
# Iter 120 of 1000 complete.
# Iter 121 of 1000 complete.
# Iter 122 of 1000 complete.
# Iter 123 of 1000 complete.
# Iter 124 of 1000 complete.
# Iter 125 of 1000 complete.
# Iter 126 of 1000 complete.
# Iter 127 of 1000 complete.
# Iter 128 of 1000 complete.
# Iter 129 of 1000 complete.
# Iter 130 of 1000 complete.
# Iter 131 of 1000 complete.
# Iter 132 of 1000 complete.
# Iter 133 of 1000 complete.
# Iter 134 of 1000 complete.
# Iter 135 of 1000 complete.
# Iter 136 of 1000 complete.
# Iter 137 of 1000 complete.
# Iter 138 of 1000 complete.
# Iter 139 of 1000 complete.
# Iter 140 of 1000 complete.
# Iter 141 of 1000 complete.
# Iter 142 of 1000 complete.
# Iter 143 of 1000 complete.
# Iter 144 of 1000 complete.
# Iter 145 of 1000 complete.
# Iter 146 of 1000 complete.
# Iter 147 of 1000 complete.
# Iter 148 of 1000 complete.
# Iter 149 of 1000 complete.
# Iter 150 of 1000 complete.
# Iter 151 of 1000 complete.
# Iter 152 of 1000 complete.
# Iter 153 of 1000 complete.
# Iter 154 of 1000 complete.
# Iter 155 of 1000 complete.
# Iter 156 of 1000 complete.
# Iter 157 of 1000 complete.
# Iter 158 of 1000 complete.
# Iter 159 of 1000 complete.
# Iter 160 of 1000 complete.
# Iter 161 of 1000 complete.
# Iter 162 of 1000 complete.
# Iter 163 of 1000 complete.
# Iter 164 of 1000 complete.
# Iter 165 of 1000 complete.
# Iter 166 of 1000 complete.
# Iter 167 of 1000 complete.
# Iter 168 of 1000 complete.
# Iter 169 of 1000 complete.
# Iter 170 of 1000 complete.
# Iter 171 of 1000 complete.
# Iter 172 of 1000 complete.
# Iter 173 of 1000 complete.
# Iter 174 of 1000 complete.
# Iter 175 of 1000 complete.
# Iter 176 of 1000 complete.
# Iter 177 of 1000 complete.
# Iter 178 of 1000 complete.
# Iter 179 of 1000 complete.
# Iter 180 of 1000 complete.
# Iter 181 of 1000 complete.
# Iter 182 of 1000 complete.
# Iter 183 of 1000 complete.
# Iter 184 of 1000 complete.
# Iter 185 of 1000 complete.
# Iter 186 of 1000 complete.
# Iter 187 of 1000 complete.
# Iter 188 of 1000 complete.
# Iter 189 of 1000 complete.
# Iter 190 of 1000 complete.
# Iter 191 of 1000 complete.
# Iter 192 of 1000 complete.
# Iter 193 of 1000 complete.
# Iter 194 of 1000 complete.
# Iter 195 of 1000 complete.
# Iter 196 of 1000 complete.
# Iter 197 of 1000 complete.
# Iter 198 of 1000 complete.
# Iter 199 of 1000 complete.
# Iter 200 of 1000 complete.
# Iter 201 of 1000 complete.
# Iter 202 of 1000 complete.
# Iter 203 of 1000 complete.
# Iter 204 of 1000 complete.
# Iter 205 of 1000 complete.
# Iter 206 of 1000 complete.
# Iter 207 of 1000 complete.
# Iter 208 of 1000 complete.
# Iter 209 of 1000 complete.
# Iter 210 of 1000 complete.
# Iter 211 of 1000 complete.
# Iter 212 of 1000 complete.
# Iter 213 of 1000 complete.
# Iter 214 of 1000 complete.
# Iter 215 of 1000 complete.
# Iter 216 of 1000 complete.
# Iter 217 of 1000 complete.
# Iter 218 of 1000 complete.
# Iter 219 of 1000 complete.
# Iter 220 of 1000 complete.
# Iter 221 of 1000 complete.
# Iter 222 of 1000 complete.
# Iter 223 of 1000 complete.
# Iter 224 of 1000 complete.
# Iter 225 of 1000 complete.
# Iter 226 of 1000 complete.
# Iter 227 of 1000 complete.
# Iter 228 of 1000 complete.
# Iter 229 of 1000 complete.
# Iter 230 of 1000 complete.
# Iter 231 of 1000 complete.
# Iter 232 of 1000 complete.
# Iter 233 of 1000 complete.
# Iter 234 of 1000 complete.
# Iter 235 of 1000 complete.
# Iter 236 of 1000 complete.
# Iter 237 of 1000 complete.
# Iter 238 of 1000 complete.
# Iter 239 of 1000 complete.
# Iter 240 of 1000 complete.
# Iter 241 of 1000 complete.
# Iter 242 of 1000 complete.
# Iter 243 of 1000 complete.
# Iter 244 of 1000 complete.
# Iter 245 of 1000 complete.
# Iter 246 of 1000 complete.
# Iter 247 of 1000 complete.
# Iter 248 of 1000 complete.
# Iter 249 of 1000 complete.
# Iter 250 of 1000 complete.
# Iter 251 of 1000 complete.
# Iter 252 of 1000 complete.
# Iter 253 of 1000 complete.
# Iter 254 of 1000 complete.
# Iter 255 of 1000 complete.
# Iter 256 of 1000 complete.
# Iter 257 of 1000 complete.
# Iter 258 of 1000 complete.
# Iter 259 of 1000 complete.
# Iter 260 of 1000 complete.
# Iter 261 of 1000 complete.
# Iter 262 of 1000 complete.
# Iter 263 of 1000 complete.
# Iter 264 of 1000 complete.
# Iter 265 of 1000 complete.
# Iter 266 of 1000 complete.
# Iter 267 of 1000 complete.
# Iter 268 of 1000 complete.
# Iter 269 of 1000 complete.
# Iter 270 of 1000 complete.
# Iter 271 of 1000 complete.
# Iter 272 of 1000 complete.
# Iter 273 of 1000 complete.
# Iter 274 of 1000 complete.
# Iter 275 of 1000 complete.
# Iter 276 of 1000 complete.
# Iter 277 of 1000 complete.
# Iter 278 of 1000 complete.
# Iter 279 of 1000 complete.
# Iter 280 of 1000 complete.
# Iter 281 of 1000 complete.
# Iter 282 of 1000 complete.
# Iter 283 of 1000 complete.
# Iter 284 of 1000 complete.
# Iter 285 of 1000 complete.
# Iter 286 of 1000 complete.
# Iter 287 of 1000 complete.
# Iter 288 of 1000 complete.
# Iter 289 of 1000 complete.
# Iter 290 of 1000 complete.
# Iter 291 of 1000 complete.
# Iter 292 of 1000 complete.
# Iter 293 of 1000 complete.
# Iter 294 of 1000 complete.
# Iter 295 of 1000 complete.
# Iter 296 of 1000 complete.
# Iter 297 of 1000 complete.
# Iter 298 of 1000 complete.
# Iter 299 of 1000 complete.
# Iter 300 of 1000 complete.
# Iter 301 of 1000 complete.
# Iter 302 of 1000 complete.
# Iter 303 of 1000 complete.
# Iter 304 of 1000 complete.
# Iter 305 of 1000 complete.
# Iter 306 of 1000 complete.
# Iter 307 of 1000 complete.
# Iter 308 of 1000 complete.
# Iter 309 of 1000 complete.
# Iter 310 of 1000 complete.
# Iter 311 of 1000 complete.
# Iter 312 of 1000 complete.
# Iter 313 of 1000 complete.
# Iter 314 of 1000 complete.
# Iter 315 of 1000 complete.
# Iter 316 of 1000 complete.
# Iter 317 of 1000 complete.
# Iter 318 of 1000 complete.
# Iter 319 of 1000 complete.
# Iter 320 of 1000 complete.
# Iter 321 of 1000 complete.
# Iter 322 of 1000 complete.
# Iter 323 of 1000 complete.
# Iter 324 of 1000 complete.
# Iter 325 of 1000 complete.
# Iter 326 of 1000 complete.
# Iter 327 of 1000 complete.
# Iter 328 of 1000 complete.
# Iter 329 of 1000 complete.
# Iter 330 of 1000 complete.
# Iter 331 of 1000 complete.
# Iter 332 of 1000 complete.
# Iter 333 of 1000 complete.
# Iter 334 of 1000 complete.
# Iter 335 of 1000 complete.
# Iter 336 of 1000 complete.
# Iter 337 of 1000 complete.
# Iter 338 of 1000 complete.
# Iter 339 of 1000 complete.
# Iter 340 of 1000 complete.
# Iter 341 of 1000 complete.
# Iter 342 of 1000 complete.
# Iter 343 of 1000 complete.
# Iter 344 of 1000 complete.
# Iter 345 of 1000 complete.
# Iter 346 of 1000 complete.
# Iter 347 of 1000 complete.
# Iter 348 of 1000 complete.
# Iter 349 of 1000 complete.
# Iter 350 of 1000 complete.
# Iter 351 of 1000 complete.
# Iter 352 of 1000 complete.
# Iter 353 of 1000 complete.
# Iter 354 of 1000 complete.
# Iter 355 of 1000 complete.
# Iter 356 of 1000 complete.
# Iter 357 of 1000 complete.
# Iter 358 of 1000 complete.
# Iter 359 of 1000 complete.
# Iter 360 of 1000 complete.
# Iter 361 of 1000 complete.
# Iter 362 of 1000 complete.
# Iter 363 of 1000 complete.
# Iter 364 of 1000 complete.
# Iter 365 of 1000 complete.
# Iter 366 of 1000 complete.
# Iter 367 of 1000 complete.
# Iter 368 of 1000 complete.
# Iter 369 of 1000 complete.
# Iter 370 of 1000 complete.
# Iter 371 of 1000 complete.
# Iter 372 of 1000 complete.
# Iter 373 of 1000 complete.
# Iter 374 of 1000 complete.
# Iter 375 of 1000 complete.
# Iter 376 of 1000 complete.
# Iter 377 of 1000 complete.
# Iter 378 of 1000 complete.
# Iter 379 of 1000 complete.
# Iter 380 of 1000 complete.
# Iter 381 of 1000 complete.
# Iter 382 of 1000 complete.
# Iter 383 of 1000 complete.
# Iter 384 of 1000 complete.
# Iter 385 of 1000 complete.
# Iter 386 of 1000 complete.
# Iter 387 of 1000 complete.
# Iter 388 of 1000 complete.
# Iter 389 of 1000 complete.
# Iter 390 of 1000 complete.
# Iter 391 of 1000 complete.
# Iter 392 of 1000 complete.
# Iter 393 of 1000 complete.
# Iter 394 of 1000 complete.
# Iter 395 of 1000 complete.
# Iter 396 of 1000 complete.
# Iter 397 of 1000 complete.
# Iter 398 of 1000 complete.
# Iter 399 of 1000 complete.
# Iter 400 of 1000 complete.
# Iter 401 of 1000 complete.
# Iter 402 of 1000 complete.
# Iter 403 of 1000 complete.
# Iter 404 of 1000 complete.
# Iter 405 of 1000 complete.
# Iter 406 of 1000 complete.
# Iter 407 of 1000 complete.
# Iter 408 of 1000 complete.
# Iter 409 of 1000 complete.
# Iter 410 of 1000 complete.
# Iter 411 of 1000 complete.
# Iter 412 of 1000 complete.
# Iter 413 of 1000 complete.
# Iter 414 of 1000 complete.
# Iter 415 of 1000 complete.
# Iter 416 of 1000 complete.
# Iter 417 of 1000 complete.
# Iter 418 of 1000 complete.
# Iter 419 of 1000 complete.
# Iter 420 of 1000 complete.
# Iter 421 of 1000 complete.
# Iter 422 of 1000 complete.
# Iter 423 of 1000 complete.
# Iter 424 of 1000 complete.
# Iter 425 of 1000 complete.
# Iter 426 of 1000 complete.
# Iter 427 of 1000 complete.
# Iter 428 of 1000 complete.
# Iter 429 of 1000 complete.
# Iter 430 of 1000 complete.
# Iter 431 of 1000 complete.
# Iter 432 of 1000 complete.
# Iter 433 of 1000 complete.
# Iter 434 of 1000 complete.
# Iter 435 of 1000 complete.
# Iter 436 of 1000 complete.
# Iter 437 of 1000 complete.
# Iter 438 of 1000 complete.
# Iter 439 of 1000 complete.
# Iter 440 of 1000 complete.
# Iter 441 of 1000 complete.
# Iter 442 of 1000 complete.
# Iter 443 of 1000 complete.
# Iter 444 of 1000 complete.
# Iter 445 of 1000 complete.
# Iter 446 of 1000 complete.
# Iter 447 of 1000 complete.
# Iter 448 of 1000 complete.
# Iter 449 of 1000 complete.
# Iter 450 of 1000 complete.
# Iter 451 of 1000 complete.
# Iter 452 of 1000 complete.
# Iter 453 of 1000 complete.
# Iter 454 of 1000 complete.
# Iter 455 of 1000 complete.
# Iter 456 of 1000 complete.
# Iter 457 of 1000 complete.
# Iter 458 of 1000 complete.
# Iter 459 of 1000 complete.
# Iter 460 of 1000 complete.
# Iter 461 of 1000 complete.
# Iter 462 of 1000 complete.
# Iter 463 of 1000 complete.
# Iter 464 of 1000 complete.
# Iter 465 of 1000 complete.
# Iter 466 of 1000 complete.
# Iter 467 of 1000 complete.
# Iter 468 of 1000 complete.
# Iter 469 of 1000 complete.
# Iter 470 of 1000 complete.
# Iter 471 of 1000 complete.
# Iter 472 of 1000 complete.
# Iter 473 of 1000 complete.
# Iter 474 of 1000 complete.
# Iter 475 of 1000 complete.
# Iter 476 of 1000 complete.
# Iter 477 of 1000 complete.
# Iter 478 of 1000 complete.
# Iter 479 of 1000 complete.
# Iter 480 of 1000 complete.
# Iter 481 of 1000 complete.
# Iter 482 of 1000 complete.
# Iter 483 of 1000 complete.
# Iter 484 of 1000 complete.
# Iter 485 of 1000 complete.
# Iter 486 of 1000 complete.
# Iter 487 of 1000 complete.
# Iter 488 of 1000 complete.
# Iter 489 of 1000 complete.
# Iter 490 of 1000 complete.
# Iter 491 of 1000 complete.
# Iter 492 of 1000 complete.
# Iter 493 of 1000 complete.
# Iter 494 of 1000 complete.
# Iter 495 of 1000 complete.
# Iter 496 of 1000 complete.
# Iter 497 of 1000 complete.
# Iter 498 of 1000 complete.
# Iter 499 of 1000 complete.
# Iter 500 of 1000 complete.
# Iter 501 of 1000 complete.
# Iter 502 of 1000 complete.
# Iter 503 of 1000 complete.
# Iter 504 of 1000 complete.
# Iter 505 of 1000 complete.
# Iter 506 of 1000 complete.
# Iter 507 of 1000 complete.
# Iter 508 of 1000 complete.
# Iter 509 of 1000 complete.
# Iter 510 of 1000 complete.
# Iter 511 of 1000 complete.
# Iter 512 of 1000 complete.
# Iter 513 of 1000 complete.
# Iter 514 of 1000 complete.
# Iter 515 of 1000 complete.
# Iter 516 of 1000 complete.
# Iter 517 of 1000 complete.
# Iter 518 of 1000 complete.
# Iter 519 of 1000 complete.
# Iter 520 of 1000 complete.
# Iter 521 of 1000 complete.
# Iter 522 of 1000 complete.
# Iter 523 of 1000 complete.
# Iter 524 of 1000 complete.
# Iter 525 of 1000 complete.
# Iter 526 of 1000 complete.
# Iter 527 of 1000 complete.
# Iter 528 of 1000 complete.
# Iter 529 of 1000 complete.
# Iter 530 of 1000 complete.
# Iter 531 of 1000 complete.
# Iter 532 of 1000 complete.
# Iter 533 of 1000 complete.
# Iter 534 of 1000 complete.
# Iter 535 of 1000 complete.
# Iter 536 of 1000 complete.
# Iter 537 of 1000 complete.
# Iter 538 of 1000 complete.
# Iter 539 of 1000 complete.
# Iter 540 of 1000 complete.
# Iter 541 of 1000 complete.
# Iter 542 of 1000 complete.
# Iter 543 of 1000 complete.
# Iter 544 of 1000 complete.
# Iter 545 of 1000 complete.
# Iter 546 of 1000 complete.
# Iter 547 of 1000 complete.
# Iter 548 of 1000 complete.
# Iter 549 of 1000 complete.
# Iter 550 of 1000 complete.
# Iter 551 of 1000 complete.
# Iter 552 of 1000 complete.
# Iter 553 of 1000 complete.
# Iter 554 of 1000 complete.
# Iter 555 of 1000 complete.
# Iter 556 of 1000 complete.
# Iter 557 of 1000 complete.
# Iter 558 of 1000 complete.
# Iter 559 of 1000 complete.
# Iter 560 of 1000 complete.
# Iter 561 of 1000 complete.
# Iter 562 of 1000 complete.
# Iter 563 of 1000 complete.
# Iter 564 of 1000 complete.
# Iter 565 of 1000 complete.
# Iter 566 of 1000 complete.
# Iter 567 of 1000 complete.
# Iter 568 of 1000 complete.
# Iter 569 of 1000 complete.
# Iter 570 of 1000 complete.
# Iter 571 of 1000 complete.
# Iter 572 of 1000 complete.
# Iter 573 of 1000 complete.
# Iter 574 of 1000 complete.
# Iter 575 of 1000 complete.
# Iter 576 of 1000 complete.
# Iter 577 of 1000 complete.
# Iter 578 of 1000 complete.
# Iter 579 of 1000 complete.
# Iter 580 of 1000 complete.
# Iter 581 of 1000 complete.
# Iter 582 of 1000 complete.
# Iter 583 of 1000 complete.
# Iter 584 of 1000 complete.
# Iter 585 of 1000 complete.
# Iter 586 of 1000 complete.
# Iter 587 of 1000 complete.
# Iter 588 of 1000 complete.
# Iter 589 of 1000 complete.
# Iter 590 of 1000 complete.
# Iter 591 of 1000 complete.
# Iter 592 of 1000 complete.
# Iter 593 of 1000 complete.
# Iter 594 of 1000 complete.
# Iter 595 of 1000 complete.
# Iter 596 of 1000 complete.
# Iter 597 of 1000 complete.
# Iter 598 of 1000 complete.
# Iter 599 of 1000 complete.
# Iter 600 of 1000 complete.
# Iter 601 of 1000 complete.
# Iter 602 of 1000 complete.
# Iter 603 of 1000 complete.
# Iter 604 of 1000 complete.
# Iter 605 of 1000 complete.
# Iter 606 of 1000 complete.
# Iter 607 of 1000 complete.
# Iter 608 of 1000 complete.
# Iter 609 of 1000 complete.
# Iter 610 of 1000 complete.
# Iter 611 of 1000 complete.
# Iter 612 of 1000 complete.
# Iter 613 of 1000 complete.
# Iter 614 of 1000 complete.
# Iter 615 of 1000 complete.
# Iter 616 of 1000 complete.
# Iter 617 of 1000 complete.
# Iter 618 of 1000 complete.
# Iter 619 of 1000 complete.
# Iter 620 of 1000 complete.
# Iter 621 of 1000 complete.
# Iter 622 of 1000 complete.
# Iter 623 of 1000 complete.
# Iter 624 of 1000 complete.
# Iter 625 of 1000 complete.
# Iter 626 of 1000 complete.
# Iter 627 of 1000 complete.
# Iter 628 of 1000 complete.
# Iter 629 of 1000 complete.
# Iter 630 of 1000 complete.
# Iter 631 of 1000 complete.
# Iter 632 of 1000 complete.
# Iter 633 of 1000 complete.
# Iter 634 of 1000 complete.
# Iter 635 of 1000 complete.
# Iter 636 of 1000 complete.
# Iter 637 of 1000 complete.
# Iter 638 of 1000 complete.
# Iter 639 of 1000 complete.
# Iter 640 of 1000 complete.
# Iter 641 of 1000 complete.
# Iter 642 of 1000 complete.
# Iter 643 of 1000 complete.
# Iter 644 of 1000 complete.
# Iter 645 of 1000 complete.
# Iter 646 of 1000 complete.
# Iter 647 of 1000 complete.
# Iter 648 of 1000 complete.
# Iter 649 of 1000 complete.
# Iter 650 of 1000 complete.
# Iter 651 of 1000 complete.
# Iter 652 of 1000 complete.
# Iter 653 of 1000 complete.
# Iter 654 of 1000 complete.
# Iter 655 of 1000 complete.
# Iter 656 of 1000 complete.
# Iter 657 of 1000 complete.
# Iter 658 of 1000 complete.
# Iter 659 of 1000 complete.
# Iter 660 of 1000 complete.
# Iter 661 of 1000 complete.
# Iter 662 of 1000 complete.
# Iter 663 of 1000 complete.
# Iter 664 of 1000 complete.
# Iter 665 of 1000 complete.
# Iter 666 of 1000 complete.
# Iter 667 of 1000 complete.
# Iter 668 of 1000 complete.
# Iter 669 of 1000 complete.
# Iter 670 of 1000 complete.
# Iter 671 of 1000 complete.
# Iter 672 of 1000 complete.
# Iter 673 of 1000 complete.
# Iter 674 of 1000 complete.
# Iter 675 of 1000 complete.
# Iter 676 of 1000 complete.
# Iter 677 of 1000 complete.
# Iter 678 of 1000 complete.
# Iter 679 of 1000 complete.
# Iter 680 of 1000 complete.
# Iter 681 of 1000 complete.
# Iter 682 of 1000 complete.
# Iter 683 of 1000 complete.
# Iter 684 of 1000 complete.
# Iter 685 of 1000 complete.
# Iter 686 of 1000 complete.
# Iter 687 of 1000 complete.
# Iter 688 of 1000 complete.
# Iter 689 of 1000 complete.
# Iter 690 of 1000 complete.
# Iter 691 of 1000 complete.
# Iter 692 of 1000 complete.
# Iter 693 of 1000 complete.
# Iter 694 of 1000 complete.
# Iter 695 of 1000 complete.
# Iter 696 of 1000 complete.
# Iter 697 of 1000 complete.
# Iter 698 of 1000 complete.
# Iter 699 of 1000 complete.
# Iter 700 of 1000 complete.
# Iter 701 of 1000 complete.
# Iter 702 of 1000 complete.
# Iter 703 of 1000 complete.
# Iter 704 of 1000 complete.
# Iter 705 of 1000 complete.
# Iter 706 of 1000 complete.
# Iter 707 of 1000 complete.
# Iter 708 of 1000 complete.
# Iter 709 of 1000 complete.
# Iter 710 of 1000 complete.
# Iter 711 of 1000 complete.
# Iter 712 of 1000 complete.
# Iter 713 of 1000 complete.
# Iter 714 of 1000 complete.
# Iter 715 of 1000 complete.
# Iter 716 of 1000 complete.
# Iter 717 of 1000 complete.
# Iter 718 of 1000 complete.
# Iter 719 of 1000 complete.
# Iter 720 of 1000 complete.
# Iter 721 of 1000 complete.
# Iter 722 of 1000 complete.
# Iter 723 of 1000 complete.
# Iter 724 of 1000 complete.
# Iter 725 of 1000 complete.
# Iter 726 of 1000 complete.
# Iter 727 of 1000 complete.
# Iter 728 of 1000 complete.
# Iter 729 of 1000 complete.
# Iter 730 of 1000 complete.
# Iter 731 of 1000 complete.
# Iter 732 of 1000 complete.
# Iter 733 of 1000 complete.
# Iter 734 of 1000 complete.
# Iter 735 of 1000 complete.
# Iter 736 of 1000 complete.
# Iter 737 of 1000 complete.
# Iter 738 of 1000 complete.
# Iter 739 of 1000 complete.
# Iter 740 of 1000 complete.
# Iter 741 of 1000 complete.
# Iter 742 of 1000 complete.
# Iter 743 of 1000 complete.
# Iter 744 of 1000 complete.
# Iter 745 of 1000 complete.
# Iter 746 of 1000 complete.
# Iter 747 of 1000 complete.
# Iter 748 of 1000 complete.
# Iter 749 of 1000 complete.
# Iter 750 of 1000 complete.
# Iter 751 of 1000 complete.
# Iter 752 of 1000 complete.
# Iter 753 of 1000 complete.
# Iter 754 of 1000 complete.
# Iter 755 of 1000 complete.
# Iter 756 of 1000 complete.
# Iter 757 of 1000 complete.
# Iter 758 of 1000 complete.
# Iter 759 of 1000 complete.
# Iter 760 of 1000 complete.
# Iter 761 of 1000 complete.
# Iter 762 of 1000 complete.
# Iter 763 of 1000 complete.
# Iter 764 of 1000 complete.
# Iter 765 of 1000 complete.
# Iter 766 of 1000 complete.
# Iter 767 of 1000 complete.
# Iter 768 of 1000 complete.
# Iter 769 of 1000 complete.
# Iter 770 of 1000 complete.
# Iter 771 of 1000 complete.
# Iter 772 of 1000 complete.
# Iter 773 of 1000 complete.
# Iter 774 of 1000 complete.
# Iter 775 of 1000 complete.
# Iter 776 of 1000 complete.
# Iter 777 of 1000 complete.
# Iter 778 of 1000 complete.
# Iter 779 of 1000 complete.
# Iter 780 of 1000 complete.
# Iter 781 of 1000 complete.
# Iter 782 of 1000 complete.
# Iter 783 of 1000 complete.
# Iter 784 of 1000 complete.
# Iter 785 of 1000 complete.
# Iter 786 of 1000 complete.
# Iter 787 of 1000 complete.
# Iter 788 of 1000 complete.
# Iter 789 of 1000 complete.
# Iter 790 of 1000 complete.
# Iter 791 of 1000 complete.
# Iter 792 of 1000 complete.
# Iter 793 of 1000 complete.
# Iter 794 of 1000 complete.
# Iter 795 of 1000 complete.
# Iter 796 of 1000 complete.
# Iter 797 of 1000 complete.
# Iter 798 of 1000 complete.
# Iter 799 of 1000 complete.
# Iter 800 of 1000 complete.
# Iter 801 of 1000 complete.
# Iter 802 of 1000 complete.
# Iter 803 of 1000 complete.
# Iter 804 of 1000 complete.
# Iter 805 of 1000 complete.
# Iter 806 of 1000 complete.
# Iter 807 of 1000 complete.
# Iter 808 of 1000 complete.
# Iter 809 of 1000 complete.
# Iter 810 of 1000 complete.
# Iter 811 of 1000 complete.
# Iter 812 of 1000 complete.
# Iter 813 of 1000 complete.
# Iter 814 of 1000 complete.
# Iter 815 of 1000 complete.
# Iter 816 of 1000 complete.
# Iter 817 of 1000 complete.
# Iter 818 of 1000 complete.
# Iter 819 of 1000 complete.
# Iter 820 of 1000 complete.
# Iter 821 of 1000 complete.
# Iter 822 of 1000 complete.
# Iter 823 of 1000 complete.
# Iter 824 of 1000 complete.
# Iter 825 of 1000 complete.
# Iter 826 of 1000 complete.
# Iter 827 of 1000 complete.
# Iter 828 of 1000 complete.
# Iter 829 of 1000 complete.
# Iter 830 of 1000 complete.
# Iter 831 of 1000 complete.
# Iter 832 of 1000 complete.
# Iter 833 of 1000 complete.
# Iter 834 of 1000 complete.
# Iter 835 of 1000 complete.
# Iter 836 of 1000 complete.
# Iter 837 of 1000 complete.
# Iter 838 of 1000 complete.
# Iter 839 of 1000 complete.
# Iter 840 of 1000 complete.
# Iter 841 of 1000 complete.
# Iter 842 of 1000 complete.
# Iter 843 of 1000 complete.
# Iter 844 of 1000 complete.
# Iter 845 of 1000 complete.
# Iter 846 of 1000 complete.
# Iter 847 of 1000 complete.
# Iter 848 of 1000 complete.
# Iter 849 of 1000 complete.
# Iter 850 of 1000 complete.
# Iter 851 of 1000 complete.
# Iter 852 of 1000 complete.
# Iter 853 of 1000 complete.
# Iter 854 of 1000 complete.
# Iter 855 of 1000 complete.
# Iter 856 of 1000 complete.
# Iter 857 of 1000 complete.
# Iter 858 of 1000 complete.
# Iter 859 of 1000 complete.
# Iter 860 of 1000 complete.
# Iter 861 of 1000 complete.
# Iter 862 of 1000 complete.
# Iter 863 of 1000 complete.
# Iter 864 of 1000 complete.
# Iter 865 of 1000 complete.
# Iter 866 of 1000 complete.
# Iter 867 of 1000 complete.
# Iter 868 of 1000 complete.
# Iter 869 of 1000 complete.
# Iter 870 of 1000 complete.
# Iter 871 of 1000 complete.
# Iter 872 of 1000 complete.
# Iter 873 of 1000 complete.
# Iter 874 of 1000 complete.
# Iter 875 of 1000 complete.
# Iter 876 of 1000 complete.
# Iter 877 of 1000 complete.
# Iter 878 of 1000 complete.
# Iter 879 of 1000 complete.
# Iter 880 of 1000 complete.
# Iter 881 of 1000 complete.
# Iter 882 of 1000 complete.
# Iter 883 of 1000 complete.
# Iter 884 of 1000 complete.
# Iter 885 of 1000 complete.
# Iter 886 of 1000 complete.
# Iter 887 of 1000 complete.
# Iter 888 of 1000 complete.
# Iter 889 of 1000 complete.
# Iter 890 of 1000 complete.
# Iter 891 of 1000 complete.
# Iter 892 of 1000 complete.
# Iter 893 of 1000 complete.
# Iter 894 of 1000 complete.
# Iter 895 of 1000 complete.
# Iter 896 of 1000 complete.
# Iter 897 of 1000 complete.
# Iter 898 of 1000 complete.
# Iter 899 of 1000 complete.
# Iter 900 of 1000 complete.
# Iter 901 of 1000 complete.
# Iter 902 of 1000 complete.
# Iter 903 of 1000 complete.
# Iter 904 of 1000 complete.
# Iter 905 of 1000 complete.
# Iter 906 of 1000 complete.
# Iter 907 of 1000 complete.
# Iter 908 of 1000 complete.
# Iter 909 of 1000 complete.
# Iter 910 of 1000 complete.
# Iter 911 of 1000 complete.
# Iter 912 of 1000 complete.
# Iter 913 of 1000 complete.
# Iter 914 of 1000 complete.
# Iter 915 of 1000 complete.
# Iter 916 of 1000 complete.
# Iter 917 of 1000 complete.
# Iter 918 of 1000 complete.
# Iter 919 of 1000 complete.
# Iter 920 of 1000 complete.
# Iter 921 of 1000 complete.
# Iter 922 of 1000 complete.
# Iter 923 of 1000 complete.
# Iter 924 of 1000 complete.
# Iter 925 of 1000 complete.
# Iter 926 of 1000 complete.
# Iter 927 of 1000 complete.
# Iter 928 of 1000 complete.
# Iter 929 of 1000 complete.
# Iter 930 of 1000 complete.
# Iter 931 of 1000 complete.
# Iter 932 of 1000 complete.
# Iter 933 of 1000 complete.
# Iter 934 of 1000 complete.
# Iter 935 of 1000 complete.
# Iter 936 of 1000 complete.
# Iter 937 of 1000 complete.
# Iter 938 of 1000 complete.
# Iter 939 of 1000 complete.
# Iter 940 of 1000 complete.
# Iter 941 of 1000 complete.
# Iter 942 of 1000 complete.
# Iter 943 of 1000 complete.
# Iter 944 of 1000 complete.
# Iter 945 of 1000 complete.
# Iter 946 of 1000 complete.
# Iter 947 of 1000 complete.
# Iter 948 of 1000 complete.
# Iter 949 of 1000 complete.
# Iter 950 of 1000 complete.
# Iter 951 of 1000 complete.
# Iter 952 of 1000 complete.
# Iter 953 of 1000 complete.
# Iter 954 of 1000 complete.
# Iter 955 of 1000 complete.
# Iter 956 of 1000 complete.
# Iter 957 of 1000 complete.
# Iter 958 of 1000 complete.
# Iter 959 of 1000 complete.
# Iter 960 of 1000 complete.
# Iter 961 of 1000 complete.
# Iter 962 of 1000 complete.
# Iter 963 of 1000 complete.
# Iter 964 of 1000 complete.
# Iter 965 of 1000 complete.
# Iter 966 of 1000 complete.
# Iter 967 of 1000 complete.
# Iter 968 of 1000 complete.
# Iter 969 of 1000 complete.
# Iter 970 of 1000 complete.
# Iter 971 of 1000 complete.
# Iter 972 of 1000 complete.
# Iter 973 of 1000 complete.
# Iter 974 of 1000 complete.
# Iter 975 of 1000 complete.
# Iter 976 of 1000 complete.
# Iter 977 of 1000 complete.
# Iter 978 of 1000 complete.
# Iter 979 of 1000 complete.
# Iter 980 of 1000 complete.
# Iter 981 of 1000 complete.
# Iter 982 of 1000 complete.
# Iter 983 of 1000 complete.
# Iter 984 of 1000 complete.
# Iter 985 of 1000 complete.
# Iter 986 of 1000 complete.
# Iter 987 of 1000 complete.
# Iter 988 of 1000 complete.
# Iter 989 of 1000 complete.
# Iter 990 of 1000 complete.
# Iter 991 of 1000 complete.
# Iter 992 of 1000 complete.
# Iter 993 of 1000 complete.
# Iter 994 of 1000 complete.
# Iter 995 of 1000 complete.
# Iter 996 of 1000 complete.
# Iter 997 of 1000 complete.
# Iter 998 of 1000 complete.
# Iter 999 of 1000 complete.

# %%
import matplotlib.pyplot as plt

# %%
np.array(scores).mean()
# Out:
# 95.342

# %%
plt.hist(scores, bins=30);
# Out:
# <img src="data:image/png;base64,..." width="360">
