# %% [markdown]
# # Less Trivial Agent
#
# Goes between probing and hunting modes.  When probing, randomly samples the space.  Enters hunting on hit.  When hunting, searches region around the last hit using a queue.

# %%
# %matplotlib notebook

# %%
from board import Board
from less_trivial_agent import LessTrivialAgent

# %%
b = Board()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
a = LessTrivialAgent(b)
a.play_until_completion()
# Out:
# 58

# %% [markdown]
# ## multiple runs to collect summary statistics

# %%
n = 1000 
scores = list() 

for i in range(n): 
    board = Board(vis=False, playmode=False)
    agent = LessTrivialAgent(board)
    
    scores.append(agent.play_until_completion())
    if i %100 == 0: 
        print(f"Iter {i} of {n} complete.")
# Out:
# Iter 0 of 1000 complete.
# Iter 100 of 1000 complete.
# Iter 200 of 1000 complete.
# Iter 300 of 1000 complete.
# Iter 400 of 1000 complete.
# Iter 500 of 1000 complete.
# Iter 600 of 1000 complete.
# Iter 700 of 1000 complete.
# Iter 800 of 1000 complete.
# Iter 900 of 1000 complete.

# %%
import matplotlib.pyplot as plt

# %%
np.array(scores).mean()
# Out:
# 67.202

# %%
plt.hist(scores, bins=30)
plt.title('Histogram of slightly smarter agent score')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Histogram of slightly smarter agent score')
